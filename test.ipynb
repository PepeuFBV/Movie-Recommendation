# %%
import pandas as pd

df = pd.read_csv('data/final_data/movies_full.csv')

df
# Out:
#        movie_id  imdb_id  tmdb_id  \
# 0        113048       14    82120
# 1         32898      417      775
# 2         49389      439     5698
# 3        127054     4008   100246
# 4         93333     4936    53410
# ...         ...      ...      ...
# 17451    122147  4186390   315362
# 17452    129826  4189260   322456
# 17453    125918  4189442   305932
# 17454    126482  4191054   302429
# 17455    128612  4358230   319999
#
#                                             primaryTitle  \
# 0                                    The Waterer Watered
# 1                                     A Trip to the Moon
# 2                                The Great Train Robbery
# 3                                    Gertie the Dinosaur
# 4                                               The Bank
# ...                                                  ...
# 17451                                           Familjen
# 17452  Lego DC Comics Super Heroes: Justice League vs...
# ...
