# %%
import pandas as pd

# Merging all data to an object and sending to database
movies = pd.read_csv("data/final_data/movies.csv")

# dropping imdb_id column as it is not needed
movies.drop(columns=["imdbId"], inplace=True)

print(movies.columns)
movies
# Out:
# Index(['titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear',
#        'endYear', 'runtimeMinutes', 'genres', 'movieId', 'tmdbId'],
#       dtype='object')
#        titleType                               primaryTitle  \
# 0          short                           Blacksmith Scene
# 1          short     Edison Kinetoscopic Record of a Sneeze
# 2          short                        Leaving the Factory
# 3          short                     The Arrival of a Train
# 4          short                        The Waterer Watered
# ...          ...                                        ...
# 26689      movie                        Crazy Beautiful You
# 26690      movie                              Bikes vs Cars
# 26691      movie                              Polskie gówno
# 26692      short                              Power Rangers
# 26693  tvSpecial  Aziz Ansari Live in Madison Square Garden
#
# ...

# %%
# calling tmdb api to get remaining data
import requests
import json
import time

# getting api key from file
with open("api_key.txt", "r") as f:
    api_key = f.read()
